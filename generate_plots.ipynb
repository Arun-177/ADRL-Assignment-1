# %% [markdown]
# #

# %%
with open('forplot.txt', 'r') as file:
    content = file.read()

# Split the content by lines
lines = content.splitlines()
n = len(lines)
loss_g = []
loss_d = []
loss_decoder = []
data = []
for i in range(n):
    if(i%4!=0):
        continue
    print(lines[i])
    lines[i] = lines[i].split()
    data.append(lines[i])
    loss_g.append(float(lines[i][4]))
    loss_d.append(float(lines[i][2]))
    # loss_decoder.append(float(lines[i][-1]))
# Out:
# [0/500][0/169]          Loss_D: 2.2779  Loss_G: 1.6870  D(x): 0.3501    D(G(z)): 0.2469 / 0.5485 decoder_loss: 1.1986
# [1/500][0/169]          Loss_D: 90.4624 Loss_G: 10.0000 D(x): 0.8982    D(G(z)): 1.0000 / 1.0000 decoder_loss: 0.1019
# [2/500][0/169]          Loss_D: 91.0618 Loss_G: 10.0000 D(x): 0.9294    D(G(z)): 1.0000 / 1.0000 decoder_loss: 0.0714
# [3/500][0/169]          Loss_D: 4.2895  Loss_G: 3.9267  D(x): 0.9174    D(G(z)): 0.5879 / 0.0467 decoder_loss: 0.9991
# [4/500][0/169]          Loss_D: 0.9084  Loss_G: 1.9697  D(x): 0.9272    D(G(z)): 0.2716 / 0.1271 decoder_loss: 0.9783
# [5/500][0/169]          Loss_D: 1.8298  Loss_G: 4.4046  D(x): 0.8275    D(G(z)): 0.4371 / 0.0255 decoder_loss: 0.9703
# [6/500][0/169]          Loss_D: 1.8245  Loss_G: 4.2742  D(x): 0.8923    D(G(z)): 0.6990 / 0.0195 decoder_loss: 1.0062
# [7/500][0/169]          Loss_D: 1.2752  Loss_G: 5.6923  D(x): 0.8294    D(G(z)): 0.4654 / 0.0046 decoder_loss: 0.9977
# ...

# %%
len(loss_g),len(loss_d)
# Out:
# (380, 380)

# %%
import matplotlib.pyplot as plt

# Example arrays
x_values = list(range(380))
y_values = loss_g

# Plotting the line graph
plt.plot(x_values, y_values, marker='o')

# Adding titles and labels
plt.title("Line Graph Example")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# Show the graph
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(loss_g[3:], label='Generator Loss')
plt.plot(loss_d[3:], label='Discriminator Loss')
# plt.plot(loss_decoder, label='Decoder Loss')

plt.suptitle('Loss Plot for Generator and Discriminator on augmented animal dataset',y=-0.01)

plt.xlabel('Iterations')
plt.ylabel('Loss')

# Updating and displaying the plot
plt.draw()
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example data (replace with your actual data)
# loss_g = np.random.rand(100)  # Replace with actual loss_g values
# loss_d = np.random.rand(100)  # Replace with actual loss_d values

# Plotting the loss values, skipping the first 3 elements
plt.plot(loss_g[3:], label='Generator Loss',)  # Generator loss plot
plt.plot(loss_d[3:], label='Discriminator Loss')  # Discriminator loss plot

# Adding labels and legend
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.legend()

# Move the title below the plot
plt.suptitle('Loss Plot for Generator and Discriminator',y=-0.1)

# Display the plot
plt.show()

# %%
len(loss_g)
# Out:
# 380

# %%
# with open('forplot.txt', 'r') as file:
#     content = file.read()

# # Split the content by lines
# lines = content.splitlines()
# n = len(lines)
# loss = []
# loss_d = []
# for i in range(n):
#     # if(i%4!=0):
#         # continue
#     lines[i] = lines[i].split()
#     loss.append(float(lines[i][-1]))
#     # loss_d.append(float(lines[i][2]))

# # Print the lines
# for line in lines:
#     print(line)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example data (replace with your actual data)
# loss_g = np.random.rand(100)  # Replace with actual loss_g values
# loss_d = np.random.rand(100)  # Replace with actual loss_d values

# Plotting the loss values, skipping the first 3 elements
plt.plot(loss)  # Generator loss plot
# plt.plot(loss_d[3:], label='Discriminator Loss')  # Discriminator loss plot

# Adding labels and legend
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.legend()

# Move the title below the plot
plt.suptitle('Loss vs iteration',y=-0.01)

# Display the plot
plt.show()
# Out:
# /tmp/ipykernel_87296/2594325479.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
with open('forplot.txt', 'r') as file:
    content = file.read()

# Split the content by lines
lines = content.splitlines()
n = len(lines)
data = []
train_loss = []
val_loss = []
train_acc = []
val_acc = []
for i in range(n):
    # if(i%4!=0):
        # continue
    lines[i] = lines[i].split()
    # print(lines[i])
    if('train' in lines[i]):
        train_loss.append(float(lines[i][2]))
        train_acc.append(float(lines[i][4]))
    if('val' in lines[i]):
        val_loss.append(float(lines[i][2]))
        val_acc.append(float(lines[i][4]))


print(train_loss)
print(train_acc)
print(val_loss)
print(val_acc)
# Out:
# [2.4824, 0.9809, 0.4187, 0.2111, 0.1285, 0.0804, 0.06, 0.0464, 0.0486, 0.0423]
# [0.3844, 0.8885, 0.9521, 0.9823, 0.9948, 0.9979, 0.9979, 1.0, 0.999, 1.0]
# [1.404, 0.5838, 0.3887, 0.2719, 0.2133, 0.1903, 0.1761, 0.1709, 0.1716, 0.1719]
# [0.8542, 0.9292, 0.9417, 0.9458, 0.9583, 0.9625, 0.9625, 0.9583, 0.9583, 0.9542]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example data (replace with your actual data)
# loss_g = np.random.rand(100)  # Replace with actual loss_g values
# loss_d = np.random.rand(100)  # Replace with actual loss_d values

# Plotting the loss values, skipping the first 3 elements
plt.plot(train_loss, label='Training Loss',)  # Generator loss plot
plt.plot(val_loss, label='Validation Loss')  # Discriminator loss plot




# Adding labels and legend
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.legend()

# Move the title below the plot
plt.suptitle('Plot for training error and validation error',y=-0.1)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example data (replace with your actual data)
# loss_g = np.random.rand(100)  # Replace with actual loss_g values
# loss_d = np.random.rand(100)  # Replace with actual loss_d values

# Plotting the loss values, skipping the first 3 elements
plt.plot(train_acc, label='Training Accuracy')  # Generator loss plot
plt.plot(val_acc, label='Validation Accuracy')  # Discriminator loss plot




# Adding labels and legend
plt.xlabel('Iterations')
plt.ylabel('Accuracy')
plt.legend()

# Move the title below the plot
plt.suptitle('Plot for training accuracy and validation accuracy',y=-0.1)

# Display the plot
plt.show()

# %%
loss_g
# Out:
# []
